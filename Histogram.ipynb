# %%
#Standard
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
#Stats
from scipy import stats

# %%
#Plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([  3.,   6.,   7.,  13.,   9.,  29.,  17.,   7.,   5.,   4.]),
#  array([-2.37878093, -1.92051246, -1.46224398, -1.00397551, -0.54570704,
#         -0.08743856,  0.37082991,  0.82909838,  1.28736686,  1.74563533,
#          2.2039038 ]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)
plt.hist(dataset2, color = 'indianred')
# Out:
# (array([  2.,   4.,  11.,  21.,  11.,  12.,   8.,   8.,   1.,   2.]),
#  array([-2.18530789, -1.69432882, -1.20334974, -0.71237066, -0.22139158,
#          0.2695875 ,  0.76056657,  1.25154565,  1.74252473,  2.23350381,
#          2.72448289]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, normed= True, color = 'indianred', alpha = 0.5, bins = 20)
plt.hist(dataset1, normed= True, alpha = 0.5, bins = 20)
# Out:
# (array([ 0.04364254,  0.08728508,  0.        ,  0.26185524,  0.08728508,
#          0.2182127 ,  0.30549778,  0.26185524,  0.13092762,  0.26185524,
#          0.78556571,  0.48006794,  0.2182127 ,  0.52371047,  0.13092762,
#          0.17457016,  0.13092762,  0.08728508,  0.04364254,  0.13092762]),
#  array([-2.37878093, -2.1496467 , -1.92051246, -1.69137822, -1.46224398,
#         -1.23310975, -1.00397551, -0.77484127, -0.54570704, -0.3165728 ,
#         -0.08743856,  0.14169567,  0.37082991,  0.59996415,  0.82909838,
#          1.05823262,  1.28736686,  1.51650109,  1.74563533,  1.97476957,
#          2.2039038 ]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1, data2)

# %%
sns.jointplot(data1,data2,kind='hex')
